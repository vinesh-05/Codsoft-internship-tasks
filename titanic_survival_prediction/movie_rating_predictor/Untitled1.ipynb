# %%
import pandas as pd

# %%
df=pd.read_csv("movies_data.csv")

# %%
print(df)
print(df.describe())
# Out:
#        Unnamed: 0                                Name    Year Duration  \
# 0               0                                         NaN      NaN
# 1               1  #Gadhvi (He thought he was Gandhi) -2019.0  109 min
# 2               2                         #Homecoming -2021.0   90 min
# 3               3                             #Yaaram -2019.0  110 min
# 4               4                   ...And Once Again -2010.0  105 min
# ...           ...                                 ...     ...      ...
# 15504       15504                 Zulm Ko Jala Doonga -1988.0      NaN
# 15505       15505                               Zulmi -1999.0  129 min
# 15506       15506                           Zulmi Raj -2005.0      NaN
# 15507       15507                       Zulmi Shikari -1988.0      NaN
# 15508       15508                        Zulm-O-Sitam -1998.0  130 min
#
#                  Genre  Rating Votes            Director           Actor 1  \
# ...

# %%
print(df.shape)
# Out:
# (15509, 11)

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0       0
# Name             0
# Year           528
# Duration      8269
# Genre         1877
# Rating        7590
# Votes         7589
# Director       525
# Actor 1       1617
# Actor 2       2384
# Actor 3       3144
# dtype: int64

# %%
df=df.dropna(subset="Year")

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0       0
# Name             0
# Year             0
# Duration      7866
# Genre         1841
# Rating        7062
# Votes         7061
# Director       497
# Actor 1       1488
# Actor 2       2197
# Actor 3       2907
# dtype: int64

# %%
print(df.shape)
# Out:
# (14981, 11)

# %%
df["Year"]=df["Year"].abs()

# %%
print(df)
# Out:
#        Unnamed: 0                                Name    Year Duration  \
# 1               1  #Gadhvi (He thought he was Gandhi)  2019.0  109 min
# 2               2                         #Homecoming  2021.0   90 min
# 3               3                             #Yaaram  2019.0  110 min
# 4               4                   ...And Once Again  2010.0  105 min
# 5               5                ...Aur Pyaar Ho Gaya  1997.0  147 min
# ...           ...                                 ...     ...      ...
# 15504       15504                 Zulm Ko Jala Doonga  1988.0      NaN
# 15505       15505                               Zulmi  1999.0  129 min
# 15506       15506                           Zulmi Raj  2005.0      NaN
# 15507       15507                       Zulmi Shikari  1988.0      NaN
# 15508       15508                        Zulm-O-Sitam  1998.0  130 min
#
#                         Genre  Rating Votes            Director  \
# ...

# %%
df["Duration"].value_counts()
# Out:
# Duration
# 120 min    227
# 130 min    165
# 135 min    165
# 140 min    162
# 150 min    152
#           ...
# 204 min      1
# 235 min      1
# 298 min      1
# 217 min      1
# 250 min      1
# Name: count, Length: 181, dtype: int64

# %%
df["Duration"]=df["Duration"].str.replace("min","",regex=False).str.strip()

# %%
df["Duration"]=pd.to_numeric(df["Duration"],errors="coerce")

# %%
print(df)
# Out:
#        Unnamed: 0                                Name    Year  Duration  \
# 1               1  #Gadhvi (He thought he was Gandhi)  2019.0     109.0
# 2               2                         #Homecoming  2021.0      90.0
# 3               3                             #Yaaram  2019.0     110.0
# 4               4                   ...And Once Again  2010.0     105.0
# 5               5                ...Aur Pyaar Ho Gaya  1997.0     147.0
# ...           ...                                 ...     ...       ...
# 15504       15504                 Zulm Ko Jala Doonga  1988.0       NaN
# 15505       15505                               Zulmi  1999.0     129.0
# 15506       15506                           Zulmi Raj  2005.0       NaN
# 15507       15507                       Zulmi Shikari  1988.0       NaN
# 15508       15508                        Zulm-O-Sitam  1998.0     130.0
#
#                         Genre  Rating Votes            Director  \
# ...

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0       0
# Name             0
# Year             0
# Duration      7866
# Genre         1841
# Rating        7062
# Votes         7061
# Director       497
# Actor 1       1488
# Actor 2       2197
# Actor 3       2907
# dtype: int64

# %%
df["Duration"]=df["Duration"].fillna(df["Duration"].mean())

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0       0
# Name             0
# Year             0
# Duration         0
# Genre         1841
# Rating        7062
# Votes         7061
# Director       497
# Actor 1       1488
# Actor 2       2197
# Actor 3       2907
# dtype: int64

# %%
df["Genre"]=df["Genre"].fillna(df["Genre"].mode()[0])

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0       0
# Name             0
# Year             0
# Duration         0
# Genre            0
# Rating        7062
# Votes         7061
# Director       497
# Actor 1       1488
# Actor 2       2197
# Actor 3       2907
# dtype: int64

# %%
df["Rating"]=df["Rating"].fillna(df["Rating"].mean())

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0       0
# Name             0
# Year             0
# Duration         0
# Genre            0
# Rating           0
# Votes         7061
# Director       497
# Actor 1       1488
# Actor 2       2197
# Actor 3       2907
# dtype: int64

# %%
df["Votes"].value_counts()
# Out:
# Votes
# 8        227
# 7        224
# 9        221
# 6        213
# 10       175
#         ...
# 1,925      1
# 453        1
# 3,007      1
# 561        1
# 1,496      1
# Name: count, Length: 2034, dtype: int64

# %%
df["Votes"]=pd.to_numeric(df["Votes"],errors="coerce")

# %%
df["Votes"]=df["Votes"].fillna(df["Votes"].mean())

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0       0
# Name             0
# Year             0
# Duration         0
# Genre            0
# Rating           0
# Votes            0
# Director       497
# Actor 1       1488
# Actor 2       2197
# Actor 3       2907
# dtype: int64

# %%
df.drop(columns=["Unnamed: 0","Name"],inplace=True)

# %%
print(df)
# Out:
#          Year    Duration                   Genre    Rating       Votes  \
# 1      2019.0  109.000000                   Drama  7.000000    8.000000
# 2      2021.0   90.000000          Drama, Musical  5.841621  120.839493
# 3      2019.0  110.000000         Comedy, Romance  4.400000   35.000000
# 4      2010.0  105.000000                   Drama  5.841621  120.839493
# 5      1997.0  147.000000  Comedy, Drama, Musical  4.700000  827.000000
# ...       ...         ...                     ...       ...         ...
# 15504  1988.0  128.467604                  Action  4.600000   11.000000
# 15505  1999.0  129.000000           Action, Drama  4.500000  655.000000
# 15506  2005.0  128.467604                  Action  5.841621  120.839493
# 15507  1988.0  128.467604                  Action  5.841621  120.839493
# 15508  1998.0  130.000000           Action, Drama  6.200000   20.000000
#
#                  Director           Actor 1                 Actor 2  \
# ...

# %%
df.drop(columns=["Actor 1","Actor 2","Actor 3"],inplace=True)

# %%
print(df)
# Out:
#          Year    Duration                   Genre    Rating       Votes  \
# 1      2019.0  109.000000                   Drama  7.000000    8.000000
# 2      2021.0   90.000000          Drama, Musical  5.841621  120.839493
# 3      2019.0  110.000000         Comedy, Romance  4.400000   35.000000
# 4      2010.0  105.000000                   Drama  5.841621  120.839493
# 5      1997.0  147.000000  Comedy, Drama, Musical  4.700000  827.000000
# ...       ...         ...                     ...       ...         ...
# 15504  1988.0  128.467604                  Action  4.600000   11.000000
# 15505  1999.0  129.000000           Action, Drama  4.500000  655.000000
# 15506  2005.0  128.467604                  Action  5.841621  120.839493
# 15507  1988.0  128.467604                  Action  5.841621  120.839493
# 15508  1998.0  130.000000           Action, Drama  6.200000   20.000000
#
#                  Director
# 1           Gaurav Bakshi
# 2      Soumyajit Majumdar
# ...

# %%
print(df.isnull().sum())
# Out:
# Year          0
# Duration      0
# Genre         0
# Rating        0
# Votes         0
# Director    497
# dtype: int64

# %%
df=df.dropna(subset="Director")

# %%
print(df.isnull().sum())
# Out:
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# dtype: int64

# %%
print(df)
# Out:
#          Year    Duration                   Genre    Rating       Votes  \
# 1      2019.0  109.000000                   Drama  7.000000    8.000000
# 2      2021.0   90.000000          Drama, Musical  5.841621  120.839493
# 3      2019.0  110.000000         Comedy, Romance  4.400000   35.000000
# 4      2010.0  105.000000                   Drama  5.841621  120.839493
# 5      1997.0  147.000000  Comedy, Drama, Musical  4.700000  827.000000
# ...       ...         ...                     ...       ...         ...
# 15503  1989.0  125.000000    Action, Crime, Drama  5.800000   44.000000
# 15504  1988.0  128.467604                  Action  4.600000   11.000000
# 15505  1999.0  129.000000           Action, Drama  4.500000  655.000000
# 15506  2005.0  128.467604                  Action  5.841621  120.839493
# 15508  1998.0  130.000000           Action, Drama  6.200000   20.000000
#
#                  Director
# 1           Gaurav Bakshi
# 2      Soumyajit Majumdar
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lineplot(x="Duration",y="Rating",data=df)
# Out:
# <Axes: xlabel='Duration', ylabel='Rating'>

# %%
df["Director"].value_counts()
# Out:
# Director
# Jayant Desai            58
# Kanti Shah              57
# Babubhai Mistry         50
# Mahesh Bhatt            48
# Master Bhagwan          47
#                         ..
# Salim Khan Ding-Dong     1
# Zahid Ali                1
# Gitanjali Sinha          1
# Roshanlal Bhardwaj       1
# Dinkar Kapur             1
# Name: count, Length: 5664, dtype: int64

# %%
sns.lineplot(x="Year",y="Rating",data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Rating'>

# %%
df["Genre"].value_counts()
# Out:
# Genre
# Drama                           4303
# Action                          1225
# Romance                          604
# Thriller                         589
# Drama, Romance                   516
#                                 ...
# Action, Crime, History             1
# Documentary, Musical               1
# Adventure, Fantasy, Musical        1
# Documentary, Family, History       1
# Adventure, Fantasy, Sci-Fi         1
# Name: count, Length: 474, dtype: int64

# %%
sns.lineplot(x="Genre",y="Rating",data=df)
# Out:
# <Axes: xlabel='Genre', ylabel='Rating'>

# %%
sns.lineplot(x="Votes",y="Rating",data=df)
# Out:
# <Axes: xlabel='Votes', ylabel='Rating'>

# %%
print(df.head())
# Out:
#      Year  Duration                   Genre    Rating       Votes  \
# 1  2019.0     109.0                   Drama  7.000000    8.000000
# 2  2021.0      90.0          Drama, Musical  5.841621  120.839493
# 3  2019.0     110.0         Comedy, Romance  4.400000   35.000000
# 4  2010.0     105.0                   Drama  5.841621  120.839493
# 5  1997.0     147.0  Comedy, Drama, Musical  4.700000  827.000000
#
#              Director
# 1       Gaurav Bakshi
# 2  Soumyajit Majumdar
# 3          Ovais Khan
# 4        Amol Palekar
# 5        Rahul Rawail

# %%
df["Director"].value_counts()
# Out:
# Director
# Jayant Desai            58
# Kanti Shah              57
# Babubhai Mistry         50
# Mahesh Bhatt            48
# Master Bhagwan          47
#                         ..
# Salim Khan Ding-Dong     1
# Zahid Ali                1
# Gitanjali Sinha          1
# Roshanlal Bhardwaj       1
# Dinkar Kapur             1
# Name: count, Length: 5664, dtype: int64

# %%
sns.barplot(x="Rating",y="Director",data=df)
# Out:
# <Axes: xlabel='Rating', ylabel='Director'>

# %%
df["Rating"].max()
# Out:
# np.float64(10.0)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df["Director-enc"]=le.fit_transform(df["Director"])

# %%
print(df["Director-enc"])
# Out:
# 1        1475
# 2        4884
# 3        3170
# 4         364
# 5        3633
#          ...
# 15503    4224
# 15504    2577
# 15505    2393
# 15506    2320
# 15508    2097
# Name: Director-enc, Length: 14484, dtype: int64

# %%
df["Genre"].value_counts()
# Out:
# Genre
# Drama                           4303
# Action                          1225
# Romance                          604
# Thriller                         589
# Drama, Romance                   516
#                                 ...
# Action, Crime, History             1
# Documentary, Musical               1
# Adventure, Fantasy, Musical        1
# Documentary, Family, History       1
# Adventure, Fantasy, Sci-Fi         1
# Name: count, Length: 474, dtype: int64

# %%
df["Genre-enc"]=le.fit_transform(df["Genre"])

# %%
df.drop(columns="Genre",inplace=True)

# %%
print(df)
# Out:
#          Year    Duration    Rating       Votes            Director  \
# 1      2019.0  109.000000  7.000000    8.000000       Gaurav Bakshi
# 2      2021.0   90.000000  5.841621  120.839493  Soumyajit Majumdar
# 3      2019.0  110.000000  4.400000   35.000000          Ovais Khan
# 4      2010.0  105.000000  5.841621  120.839493        Amol Palekar
# 5      1997.0  147.000000  4.700000  827.000000        Rahul Rawail
# ...       ...         ...       ...         ...                 ...
# 15503  1989.0  125.000000  5.800000   44.000000     S.P. Muthuraman
# 15504  1988.0  128.467604  4.600000   11.000000       Mahendra Shah
# 15505  1999.0  129.000000  4.500000  655.000000          Kuku Kohli
# 15506  2005.0  128.467604  5.841621  120.839493          Kiran Thej
# 15508  1998.0  130.000000  6.200000   20.000000        K.C. Bokadia
#
#        Director-enc  Genre-enc
# 1              1475        294
# 2              4884        345
# 3              3170        224
# ...

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split

# %%
x=df.drop(columns=["Rating","Director"])
y=df["Rating"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
print(x_train.shape)
# Out:
# (11587, 5)

# %%
print(x_test.shape)
# Out:
# (2897, 5)

# %%
model=XGBRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# For predictions
x_train_pred = model.predict(x_train)

# Calculate Mean Squared Error
mse_train = mean_squared_error(y_train, x_train_pred)
print("Train MSE:", mse_train)

# Calculate R^2 (Coefficient of determination)
r2_train = r2_score(y_train, x_train_pred)
print("Train R^2:", r2_train)
# Out:
# Train MSE: 0.27639024806742146
# Train R^2: 0.7371778951924364

# %%
from sklearn.metrics import mean_squared_error, r2_score

# For predictions
x_test_pred = model.predict(x_test)
mse=mean_squared_error(y_test,x_test_pred)
r2=r2_score(y_test,x_test_pred)
print(mse)
print(r2)
# Out:
# 0.777843281833435
# 0.22816144628402846
